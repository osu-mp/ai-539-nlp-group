# %% [markdown]
# <a href="https://colab.research.google.com/github/osu-mp/ai-539-nlp-group/blob/main/NLPProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Install transformers (From HuggingFace)**

# %%
# !pip install -q transformers

# %% [markdown]
# **Imports**

# %%
import argparse
import glob
import logging
import os
import pickle
import random
import re
import shutil
from typing import Dict, List, Tuple
from urllib.request import urlretrieve
import bz2
import gzip
import os
from pathlib import Path
import sys
import tarfile
import tempfile
import time
from urllib.request import urlretrieve
import zipfile

import numpy as np
import torch
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader, Dataset, RandomSampler, SequentialSampler
from torch.utils.data.distributed import DistributedSampler
from tqdm import tqdm, trange
import torch.nn.utils.prune as prune
import pdb  
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # Load BART
# Here we load the model. We have options between "bart-base" or "bart-large".

# %%
# Load the model from Hugging Face
from transformers import BartTokenizer, BartForConditionalGeneration, AdamW, BartConfig

tokenizer = BartTokenizer.from_pretrained('facebook/bart-base', add_prefix_space=True)

bart_model_huggingface = BartForConditionalGeneration.from_pretrained("facebook/bart-base")

# %% [markdown]
# Mount Google Drive

# %%
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive')
import sys
from google.colab import drive
sys.path.append(GOOGLE_DRIVE_PATH)
drive.mount('/content/drive/')

# %% [markdown]
# # Load Fairseq model
# Download bart base model from https://github.com/facebookresearch/fairseq/blob/main/examples/bart/README.md
#
# Unzip and extract model.pt
#
# Rename it to bart-base.pt
#
# Copy the model to your Google Drive

# %%
model_path = '/content/drive/MyDrive/AI539MUSSLT/bart-base.pt'
bart_model_fairseq = torch.load(model_path)
# Reference - https://github.com/facebookresearch/muss/blob/7a8d6f63a62f5ec8d340d7ce71058111adaf6b01/muss/mining/training.py#LL42C4-L43C61
for key in ['encoder.embed_tokens.weight', 'decoder.embed_tokens.weight']:
  bart_model_fairseq['model'][key] = bart_model_fairseq['model'][key][:50264, :]

# %%
# TODO
# train loop
# eval loop
# save model

# %%
# hello eugene

# %%
# im working on this cell
# continue working on this cell
